# %% [markdown]
# # Teacher Forcing in RNNs
#
# **Roberto Fierimonte** - 19/02/2018
#
# ---

# %%
import datetime
import functools
import numpy as np
import pandas as pd
import tensorflow as tf

import matplotlib.pyplot as plt
# %matplotlib inline 

tfd = tf.contrib.distributions
tfb = tf.contrib.bayesflow

# %%
time = np.arange(0, 100, 0.5)
sigma = 0.5
y = np.sin(time)
# y = 0.2 * time + 3 * np.sin(0.5 * time) - 3 * np.cos(1.5 * time)
y_tilde = y[None, :] + sigma * np.random.randn(10, len(time))

plt.plot(y_tilde[0])
plt.plot(y, 'r')
ts = y_tilde[0]

# %%
def doublewrap(function):
    """
    A decorator decorator, allowing to use the decorator to be used without
    parentheses if not arguments are provided. All arguments must be optional.
    """
    @functools.wraps(function)
    def decorator(*args, **kwargs):
        if len(args) == 1 and len(kwargs) == 0 and callable(args[0]):
            return function(args[0])
        else:
            return lambda wrapee: function(wrapee, *args, **kwargs)
    return decorator


@doublewrap
def define_scope(function, scope=None, *args, **kwargs):
    """
    A decorator for functions that define TensorFlow operations. The wrapped
    function will only be executed once. Subsequent calls to it will directly
    return the result so that operations are added to the graph only once.
    The operations added by the function live within a tf.variable_scope(). If
    this decorator is used with arguments, they will be forwarded to the
    variable scope. The scope name defaults to the name of the wrapped
    function.
    """
    attribute = '_cache_' + function.__name__
    name = scope or function.__name__
    @property
    @functools.wraps(function)
    def decorator(self):
        if not hasattr(self, attribute):
            with tf.variable_scope(name, *args, **kwargs):
                setattr(self, attribute, function(self))
        return getattr(self, attribute)
    return decorator

# %% [markdown]
# # Baseline Model

# %%
class LinearCell(tf.contrib.rnn.RNNCell):
    """
    """
    def __init__(self, output_size, state_size, reuse=None):
        super(LinearCell, self).__init__(_reuse=reuse)
        self._output_size = output_size
        self._state_size = state_size
    
    @property
    def state_size(self):
        return self._state_size
    
    @property
    def output_size(self):
        return self._output_size
    
    def call(self, inputs, state):
        state = tf.layers.dense(inputs, self._state_size) + tf.layers.dense(state, self._state_size)
        out = tf.layers.dense(state, self._output_size)
        return out, state

class SimpleSamplingCell(tf.contrib.rnn.RNNCell):
    """
    """
    def __init__(self, cell, output_size, layer, reuse=None):
        super(SimpleSamplingCell, self).__init__(_reuse=reuse)
        self._cell = cell
        self._output_size = output_size
        self._layer = layer

    @property
    def state_size(self):
        return (self._cell.state_size, self._output_size)

    @property
    def output_size(self):
        return (self._output_size)
    
    def call(self, inputs, state_and_sample):
        del inputs  # Unused.
        (state, sample) = state_and_sample
        out, state = self._cell(sample, state)
        sample = self._layer(out)
        return sample, (state, sample)
    
class BaselineModel(object):
    """
    """
    def __init__(self, cell_type='GRU', n_hidden=100):
        self._n_hidden = n_hidden
        self._cell_type = cell_type
        if cell_type == 'Linear':
            self._cell = LinearCell(1, self._n_hidden)
            self._sampling_cell = self._cell
        else:
            self._layer = tf.layers.Dense(1)
            if cell_type == 'GRU':
                self._cell = tf.contrib.rnn.GRUBlockCell(self._n_hidden)
            elif cell_type == 'LSTM':
                self._cell = tf.contrib.rnn.LSTMBlockCell(self._n_hidden)
            elif cell_type == 'RNN':
                self._cell = tf.contrib.rnn.BasicRNNCell(self._n_hidden)
            self._sampling_cell = SimpleSamplingCell(self._cell, 1, self._layer)

    def compute_forward(self, data):
        (out, hidden) = tf.nn.dynamic_rnn(self._cell, inputs=data, dtype=tf.float32)
        if self._cell_type != 'Linear':
            out = self._layer(out)
        return out, hidden    
    
    def pred_forward(self, data, last_training_point, last_hidden):
        inputs = tf.concat([last_training_point[:, None], data], 1)        
        (out, _) = tf.nn.dynamic_rnn(self._cell, inputs=inputs, initial_state=last_hidden, dtype=tf.float32)
        if self._cell_type != 'Linear':
            out = self._layer(out)
        return out
    
    def pred_forward_autoregressive(self, last_training_point, last_hidden, future=500):
        sample = last_training_point
        hidden = last_hidden
        samples = []
        
        for _ in range(future):
            (sample, hidden) = self._cell(sample, hidden)
            if self._cell_type != 'Linear':
                sample = self._layer(sample)
            samples.append(sample)
            
        return tf.transpose(tf.stack(samples, 0), [1,0,2])

# %%
tf.reset_default_graph()

seq_length = 150; cell_type = 'Linear'; n_hidden = 10
x_ = tf.placeholder(tf.float32, [None, None, 1])
x_test = tf.placeholder(tf.float32, [None, None, 1])

with tf.variable_scope(cell_type + '_' + str(n_hidden), reuse=tf.AUTO_REUSE) as scope:
    model = BaselineModel(cell_type, n_hidden)
    res, hidden = model.compute_forward(x_[:, :-1])
    loss = tf.reduce_mean(tf.reduce_sum(tf.square(res[..., 0] - x_[:, 1:, 0]), 1))/2
    optimise = tf.train.AdamOptimizer(0.001).minimize(loss)
    
    pred_tf = model.pred_forward(x_test, x_[:, -1], hidden)
    pred_ar_tf = model.pred_forward_autoregressive(x_[:, -1], hidden, future=100)

config = tf.ConfigProto(allow_soft_placement=True)
sess = tf.InteractiveSession(config=config) 
sess.run(tf.global_variables_initializer())

saver = tf.train.Saver()
errors_baseline = []; preds_baseline = []; preds_baseline_ar = []; errors_test_baseline = []

timestamp = datetime.datetime.strftime(datetime.datetime.now(), "%Y-%m-%d_%H:%M")

for i in range(10001):
    batch = ts[None, :seq_length+1]
#     batch = np.stack([ts[i:i+seq_length] for i in np.random.randint(0, 150-seq_length, 10)])    
    error = sess.run(loss, {x_: batch[..., None]})
    sess.run(optimise, {x_: batch[..., None]})
    errors_baseline.append(error)
    
    if i % 1000 == 0:
        test_batch = ts[seq_length+1:]
        test_error = sess.run(loss, {x_: test_batch[None, :, None]})
        errors_test_baseline.append(test_error)
        print('Iteration:', i, 'Training Error:', error, 'Test Error:', test_error)
        pred = sess.run(pred_tf, {x_: ts[None, :seq_length+1, None], x_test: ts[None, seq_length+1:, None]})
        pred_ar = sess.run(pred_ar_tf, {x_: ts[None, :seq_length, None]})
        preds_baseline.append(pred); preds_baseline_ar.append(pred_ar)
        
# save_path = saver.save(sess, "/mnt/workspace/baseline_{}_length_{}_iter_{}.ckpt".format(timestamp, seq_length, i))

# %%
plt.plot(errors_baseline)
plt.plot(range(0, 10001, 1000), errors_test_baseline)

# %%
fit = sess.run(res, {x_: ts[None, :150, None]})
plt.plot(ts[None, :150].T)
plt.plot(fit[..., 0].T, 'r')

# %%
plt.plot(range(100, 200), np.concatenate([ts[None, 100:150, None], pred], 1)[0], 'r')
plt.plot(range(100, 200), np.concatenate([ts[None, 100:150, None], pred_ar[:, :50]], 1)[0], 'g-')
plt.plot(range(100, 200), ts[None, 100:200].T)

# %% [markdown]
# # Our Model

# %%
class LinearMarkovianCellWithState(tf.contrib.rnn.RNNCell):
    """
    """
    def __init__(self, event_size, state_size, reuse=None):
        super(LinearMarkovianCellWithState, self).__init__(_reuse=reuse)
        self._state_size = state_size
        self._event_size = event_size
        self._A = tf.get_variable('A', shape=(state_size, state_size), dtype=tf.float32)
        self._B = tf.get_variable('B', shape=(event_size, state_size), dtype=tf.float32)
        self._c = tf.get_variable('c', shape=(event_size,), dtype=tf.float32)
        self._D = tf.get_variable('D', shape=(state_size, event_size), dtype=tf.float32)
        self._e = tf.get_variable('e', shape=(event_size,), dtype=tf.float32)
        
    @property
    def state_size(self):
        return self._state_size

    @property
    def output_size(self):
        return self._event_size

    def call(self, inputs, state):
        state = tf.matmul(state, self._A)  + tf.matmul(inputs, self._B) + self._c
        mean = tf.matmul(state, self._D) + self._e
        return mean, state
        
class RobustARGenerator(object):
    """
    Model to test
    """
    def __init__(self, data, n_hidden=100, n_samples=200, seq_length=1000, batch_size=1):
        self._data = data
        self._n_hidden = n_hidden
        self._batch_size = batch_size
        self._n_samples = n_samples
        self._seq_length = seq_length
        self._cell = LinearMarkovianCellWithState(1, self._n_hidden)
        self._gaussian_cell = 
        
        self._optimiser = tf.train.AdamOptimizer(0.001)
        self._gen_stddev = tf.nn.softplus(tf.get_variable('generative_std', shape=(), 
                                           initializer=tf.constant_initializer(1)))
#         self._gen_stddev = tf.get_variable('generative_std', shape=(), trainable=False, 
#                                            initializer=tf.constant_initializer(0.5))
        self.make_posterior
        self.compute_elbo_david
        self.E_step
        self.M_step
    
    @define_scope
    def make_posterior(self):
#         means = tf.Variable(initial_value=ts[:seq_length][None, ...], name='post_means', dtype=tf.float32)
        means = tf.Variable(initial_value=data[:1], name='post_means', dtype=tf.float32)
        self._post_stddev = tf.nn.softplus(tf.get_variable(shape=(), initializer=tf.constant_initializer(1), 
                                                           name='post_std'))
        return tfd.Independent(tfd.MultivariateNormalDiag(means, scale_identity_multiplier=self._post_stddev))
        
    @define_scope
    def make_transitional(self):
#         h0 = tf.Variable(tf.zeros((10 * self._n_samples, self._n_hidden)), name='h0', dtype=tf.float32)
#         inputs = tf.concat([tf.Variable(tf.zeros((10 * self._n_samples, 1, 1)), trainable=False, 
#                                         name='y0', dtype=tf.float32), 
#                             self._code[:, :-1]], 1)
        inputs = tf.concat([tf.zeros((self._batch_size * self._n_samples, 1, 1)), self._code[:, :-1]], 1)
        means, _ = tf.nn.dynamic_rnn(self._cell, inputs=inputs, dtype=tf.float32)
        return means
    
    @define_scope
    def compute_elbo_david(self):      
        posterior = self.make_posterior
        print(posterior.batch_shape, posterior.event_shape)
        code = tf.transpose(posterior.sample((self._batch_size * self._n_samples)), [0, 2, 1])
        print(code.shape)
        self._code = tf.reshape(code, [-1, self._seq_length, 1])
        print(self._code.shape)
        
        entropy = self._seq_length * tf.log(tf.square(self._post_stddev))
        means = self.make_transitional
        print(means.shape)
        exponent_trans = tf.square(self._code[..., 0] - means[..., 0])
        print(exponent_trans.shape)
        kl = - entropy + self._seq_length * tf.log(tf.reduce_mean(tf.reduce_sum(exponent_trans, -1)))
        
        exp1 = tf.reduce_mean(tf.reduce_sum(tf.square(posterior.mean() - self._data[:self._batch_size, ..., 0]), -1))
        num  = self._seq_length * tf.square(self._post_stddev) + exp1
        
#         reconstruction = (- self._seq_length * exp1/num - tf.square(self._seq_length * self._post_stddev)/num
#                           - self._seq_length * tf.log(num/self._seq_length))
        exponent_gen = exp1/tf.square(self._gen_stddev)
        reconstruction = (- exponent_gen - self._seq_length * tf.log(tf.square(self._gen_stddev))
                          - self._seq_length * tf.square(self._post_stddev/self._gen_stddev))
        
        return reconstruction - kl, kl, reconstruction, entropy
    
    @define_scope
    def E_step(self):
        post_var = [v for v in tf.trainable_variables() if v.name.startswith('make_posterior/')]
        return self._optimiser.minimize(-self.compute_elbo_david[0], var_list=post_var)
    
    @define_scope
    def M_step(self):
        non_post_var = [v for v in tf.trainable_variables() if not v.name.startswith('make_posterior/')]
        return self._optimiser.minimize(-self.compute_elbo_david[0], var_list=non_post_var)
    
    @define_scope
    def trans_std(self):
        posterior = self.make_posterior
        code = tf.transpose(posterior.sample((self._batch_size * self._n_samples)), [0, 2, 1])
        self._code = tf.reshape(code, [-1, self._seq_length, 1])
        means = self.make_transitional
        
        return tf.sqrt(tf.reduce_mean(
            tf.reduce_sum(tf.square(self._code[..., 0] - means[..., 0]), -1))/self._seq_length)
    
    @define_scope
    def gen_std(self):
#         posterior = self.make_posterior
#         exp1 = tf.reduce_mean(tf.reduce_sum(tf.square(posterior.mean() - self._data[:self._batch_size, ..., 0]), -1))
#         num  = self._seq_length * tf.square(self._post_stddev) + exp1
#         return tf.sqrt(num/self._seq_length)
    
        return self._gen_stddev

# %%
tf.reset_default_graph()

seq_length = 70; n_samples = 100; batch_size = 10;
data = np.tile(y_tilde[:batch_size, :seq_length], (n_samples, 1))
x_ = tf.placeholder(tf.float32, [batch_size, seq_length, 1])

gen_model = RobustARGenerator(x_, n_hidden=2, n_samples=n_samples, seq_length=seq_length, batch_size=batch_size)

sess = tf.Session()
sess.run(tf.global_variables_initializer())

elbos = []; kls = []; llks = []; test_elbos = []; preds = []; preds_greedy = []
means = []; stds = []; gen_stddevs = []; post_stddevs = []; post_samples = []; post_means = []

for i in range(25001):
    batch = data[:batch_size]
#     batch = ts[:seq_length][None, ...]
    elbo, kl, llk, entropy = sess.run(gen_model.compute_elbo_david, {x_: batch[..., None]})
    elbos.append(elbo); kls.append(kl); llks.append(llk)
    post_means.append(sess.run(tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES, 'make_posterior/post_means:0'))[0])
    post_stddevs.append(sess.run(gen_model._post_stddev))
    m = sess.run(gen_model.make_transitional, {x_: batch[..., None]})
    s = sess.run(gen_model.trans_std, {x_: batch[..., None]})
    means.append(m); stds.append(s); gen_stddevs.append(sess.run(gen_model.gen_std, {x_: batch[..., None]}))
    latents = sess.run(gen_model._code, {x_: batch[..., None]})
    post_samples.append(latents)
    
    if i % 100 == 0:
        print('Iteration:', i, 'ELBO:', elbo, 'KL:', kl, 'Reconstruction:', llk, 'Entropy:', entropy)
    
    sess.run(gen_model.E_step, {x_: batch[..., None]})
    sess.run(gen_model.M_step, {x_: batch[..., None]})
# Out:
# () (1, 70)
# (1000, 70, 1)
# (1000, 70, 1)
# (1000, 70, 1)
# (1000, 70)
# Iteration: 0 ELBO: -648.879 KL: 520.533 Reconstruction: -128.346 Entropy: 38.1519
# Iteration: 100 ELBO: -523.123 KL: 404.629 Reconstruction: -118.494 Entropy: 29.5445
# Iteration: 200 ELBO: -476.729 KL: 364.499 Reconstruction: -112.23 Entropy: 21.0731
# Iteration: 300 ELBO: -443.638 KL: 338.469 Reconstruction: -105.17 Entropy: 10.8826
# Iteration: 400 ELBO: -420.782 KL: 323.742 Reconstruction: -97.0401 Entropy: -0.655233
# Iteration: 500 ELBO: -404.426 KL: 316.012 Reconstruction: -88.4145 Entropy: -13.0162
# Iteration: 600 ELBO: -392.118 KL: 312.21 Reconstruction: -79.9077 Entropy: -25.7489
# Iteration: 700 ELBO: -381.435 KL: 309.567 Reconstruction: -71.8682 Entropy: -38.4904
# Iteration: 800 ELBO: -373.231 KL: 308.796 Reconstruction: -64.4348 Entropy: -50.9568
# Iteration: 900 ELBO: -366.212 KL: 308.586 Reconstruction: -57.6255 Entropy: -62.9142
# Iteration: 1000 ELBO: -360.775 KL: 309.363 Reconstruction: -51.4113 Entropy: -74.1878
# Iteration: 1100 ELBO: -355.011 KL: 309.391 Reconstruction: -45.6195 Entropy: -84.6751
# Iteration: 1200 ELBO: -350.65 KL: 311.043 Reconstruction: -39.6068 Entropy: -94.4643
# Iteration: 1300 ELBO: -342.383 KL: 311.114 Reconstruction: -31.2692 Entropy: -104.225
# Iteration: 1400 ELBO: -325.621 KL: 308.546 Reconstruction: -17.0745 Entropy: -116.946
# Iteration: 1500 ELBO: -312.113 KL: 305.37 Reconstruction: -6.74323 Entropy: -132.139
# Iteration: 1600 ELBO: -303.299 KL: 302.881 Reconstruction: -0.417852 Entropy: -146.766
# Iteration: 1700 ELBO: -297.834 KL: 301.789 Reconstruction: 3.95511 Entropy: -160.044
# Iteration: 1800 ELBO: -293.254 KL: 300.484 Reconstruction: 7.22951 Entropy: -172.055
# Iteration: 1900 ELBO: -290.625 KL: 300.375 Reconstruction: 9.75013 Entropy: -182.994
# Iteration: 2000 ELBO: -286.992 KL: 298.768 Reconstruction: 11.7761 Entropy: -193.04
# Iteration: 2100 ELBO: -286.154 KL: 299.606 Reconstruction: 13.4513 Entropy: -202.339
# Iteration: 2200 ELBO: -284.063 KL: 298.908 Reconstruction: 14.8451 Entropy: -211.02
# Iteration: 2300 ELBO: -282.63 KL: 298.646 Reconstruction: 16.0152 Entropy: -219.151
# Iteration: 2400 ELBO: -280.76 KL: 297.773 Reconstruction: 17.0122 Entropy: -226.837
# Iteration: 2500 ELBO: -280.246 KL: 298.104 Reconstruction: 17.8583 Entropy: -234.093
# Iteration: 2600 ELBO: -279.27 KL: 297.874 Reconstruction: 18.6035 Entropy: -241.034
# Iteration: 2700 ELBO: -278.653 KL: 297.885 Reconstruction: 19.2322 Entropy: -247.672
# Iteration: 2800 ELBO: -278.817 KL: 298.616 Reconstruction: 19.7988 Entropy: -254.023
# Iteration: 2900 ELBO: -278.418 KL: 298.693 Reconstruction: 20.2745 Entropy: -260.159
# Iteration: 3000 ELBO: -277.415 KL: 298.138 Reconstruction: 20.7224 Entropy: -266.09
# Iteration: 3100 ELBO: -276.661 KL: 297.783 Reconstruction: 21.1228 Entropy: -271.763
# Iteration: 3200 ELBO: -276.94 KL: 298.418 Reconstruction: 21.4778 Entropy: -277.287
# Iteration: 3300 ELBO: -276.708 KL: 298.459 Reconstruction: 21.7512 Entropy: -282.632
# Iteration: 3400 ELBO: -275.767 KL: 297.838 Reconstruction: 22.0709 Entropy: -287.869
# Iteration: 3500 ELBO: -276.523 KL: 298.837 Reconstruction: 22.3143 Entropy: -292.986
# Iteration: 3600 ELBO: -275.706 KL: 298.258 Reconstruction: 22.5521 Entropy: -297.952
# Iteration: 3700 ELBO: -275.276 KL: 298.037 Reconstruction: 22.7614 Entropy: -302.845
# Iteration: 3800 ELBO: -275.302 KL: 298.262 Reconstruction: 22.9602 Entropy: -307.593
# Iteration: 3900 ELBO: -275.039 KL: 298.168 Reconstruction: 23.1291 Entropy: -312.14
# Iteration: 4000 ELBO: -274.807 KL: 298.107 Reconstruction: 23.2991 Entropy: -316.687
# Iteration: 4100 ELBO: -273.881 KL: 297.332 Reconstruction: 23.4506 Entropy: -321.193
# Iteration: 4200 ELBO: -273.967 KL: 297.55 Reconstruction: 23.5833 Entropy: -325.639
# Iteration: 4300 ELBO: -274.128 KL: 297.852 Reconstruction: 23.7248 Entropy: -329.975
# Iteration: 4400 ELBO: -274.455 KL: 298.281 Reconstruction: 23.8264 Entropy: -334.124
# Iteration: 4500 ELBO: -274.122 KL: 298.058 Reconstruction: 23.9362 Entropy: -338.349
# Iteration: 4600 ELBO: -273.52 KL: 297.542 Reconstruction: 24.0224 Entropy: -342.47
# Iteration: 4700 ELBO: -273.527 KL: 297.658 Reconstruction: 24.1311 Entropy: -346.497
# Iteration: 4800 ELBO: -273.431 KL: 297.646 Reconstruction: 24.2151 Entropy: -350.448
# Iteration: 4900 ELBO: -273.857 KL: 298.162 Reconstruction: 24.3044 Entropy: -354.497
# Iteration: 5000 ELBO: -273.635 KL: 298.019 Reconstruction: 24.3847 Entropy: -358.378
# Iteration: 5100 ELBO: -273.321 KL: 297.763 Reconstruction: 24.4411 Entropy: -362.181
# Iteration: 5200 ELBO: -273.135 KL: 297.647 Reconstruction: 24.5124 Entropy: -365.853
# Iteration: 5300 ELBO: -273.695 KL: 298.277 Reconstruction: 24.5821 Entropy: -369.377
# Iteration: 5400 ELBO: -272.468 KL: 297.09 Reconstruction: 24.6226 Entropy: -373.158
# Iteration: 5500 ELBO: -272.849 KL: 297.542 Reconstruction: 24.6934 Entropy: -376.741
# Iteration: 5600 ELBO: -272.434 KL: 297.155 Reconstruction: 24.7214 Entropy: -380.301
# Iteration: 5700 ELBO: -272.346 KL: 297.104 Reconstruction: 24.7583 Entropy: -383.808
# Iteration: 5800 ELBO: -272.173 KL: 297.004 Reconstruction: 24.8308 Entropy: -387.249
# Iteration: 5900 ELBO: -272.683 KL: 297.534 Reconstruction: 24.8516 Entropy: -390.528
# Iteration: 6000 ELBO: -273.406 KL: 298.329 Reconstruction: 24.923 Entropy: -393.893
# Iteration: 6100 ELBO: -272.12 KL: 297.065 Reconstruction: 24.9447 Entropy: -397.131
# Iteration: 6200 ELBO: -272.71 KL: 297.689 Reconstruction: 24.9791 Entropy: -400.513
# Iteration: 6300 ELBO: -271.469 KL: 296.489 Reconstruction: 25.0204 Entropy: -403.903
# Iteration: 6400 ELBO: -273.262 KL: 298.307 Reconstruction: 25.0453 Entropy: -406.673
# Iteration: 6500 ELBO: -272.657 KL: 297.729 Reconstruction: 25.072 Entropy: -409.627
# Iteration: 6600 ELBO: -272.291 KL: 297.404 Reconstruction: 25.1132 Entropy: -412.752
# Iteration: 6700 ELBO: -273.038 KL: 298.162 Reconstruction: 25.1243 Entropy: -415.27
# Iteration: 6800 ELBO: -272.09 KL: 297.235 Reconstruction: 25.1452 Entropy: -417.75
# Iteration: 6900 ELBO: -272.292 KL: 297.447 Reconstruction: 25.1552 Entropy: -419.93
# Iteration: 7000 ELBO: -273.11 KL: 298.291 Reconstruction: 25.1806 Entropy: -423.252
# Iteration: 7100 ELBO: -272.587 KL: 297.789 Reconstruction: 25.2025 Entropy: -425.985
# Iteration: 7200 ELBO: -272.809 KL: 298.041 Reconstruction: 25.2319 Entropy: -428.603
# Iteration: 7300 ELBO: -272.816 KL: 298.058 Reconstruction: 25.2418 Entropy: -430.704
# Iteration: 7400 ELBO: -272.474 KL: 297.728 Reconstruction: 25.254 Entropy: -432.807
# Iteration: 7500 ELBO: -272.319 KL: 297.584 Reconstruction: 25.2652 Entropy: -435.556
# Iteration: 7600 ELBO: -272.209 KL: 297.502 Reconstruction: 25.2937 Entropy: -437.917
# Iteration: 7700 ELBO: -272.276 KL: 297.571 Reconstruction: 25.2953 Entropy: -440.044
# Iteration: 7800 ELBO: -272.336 KL: 297.648 Reconstruction: 25.3123 Entropy: -441.414
# Iteration: 7900 ELBO: -272.375 KL: 297.674 Reconstruction: 25.2987 Entropy: -443.617
# Iteration: 8000 ELBO: -272.684 KL: 298.017 Reconstruction: 25.333 Entropy: -446.313
# Iteration: 8100 ELBO: -272.273 KL: 297.6 Reconstruction: 25.3274 Entropy: -446.429
# Iteration: 8200 ELBO: -272.332 KL: 297.682 Reconstruction: 25.35 Entropy: -448.388
# Iteration: 8300 ELBO: -271.891 KL: 297.248 Reconstruction: 25.3571 Entropy: -450.661
# Iteration: 8400 ELBO: -272.138 KL: 297.498 Reconstruction: 25.3595 Entropy: -453.163
# Iteration: 8500 ELBO: -271.866 KL: 297.236 Reconstruction: 25.3705 Entropy: -454.105
# Iteration: 8600 ELBO: -272.346 KL: 297.732 Reconstruction: 25.3851 Entropy: -455.978
# Iteration: 8700 ELBO: -272.212 KL: 297.594 Reconstruction: 25.3828 Entropy: -456.164
# Iteration: 8800 ELBO: -271.717 KL: 297.118 Reconstruction: 25.4015 Entropy: -458.202
# Iteration: 8900 ELBO: -272.444 KL: 297.851 Reconstruction: 25.4064 Entropy: -460.042
# Iteration: 9000 ELBO: -272.4 KL: 297.808 Reconstruction: 25.408 Entropy: -460.897
# Iteration: 9100 ELBO: -272.182 KL: 297.596 Reconstruction: 25.4142 Entropy: -461.892
# Iteration: 9200 ELBO: -272.767 KL: 298.166 Reconstruction: 25.3995 Entropy: -462.019
# Iteration: 9300 ELBO: -272.234 KL: 297.659 Reconstruction: 25.4253 Entropy: -462.027
# Iteration: 9400 ELBO: -272.022 KL: 297.437 Reconstruction: 25.4148 Entropy: -463.36
# Iteration: 9500 ELBO: -272.02 KL: 297.439 Reconstruction: 25.4189 Entropy: -464.556
# Iteration: 9600 ELBO: -272.734 KL: 298.158 Reconstruction: 25.4235 Entropy: -465.098
# Iteration: 9700 ELBO: -272.885 KL: 298.318 Reconstruction: 25.4323 Entropy: -465.312
# Iteration: 9800 ELBO: -272.153 KL: 297.591 Reconstruction: 25.4376 Entropy: -467.129
# Iteration: 9900 ELBO: -272.397 KL: 297.827 Reconstruction: 25.4296 Entropy: -467.315
# Iteration: 10000 ELBO: -272.954 KL: 298.39 Reconstruction: 25.4362 Entropy: -469.148
# Iteration: 10100 ELBO: -272.516 KL: 297.949 Reconstruction: 25.4336 Entropy: -468.06
# Iteration: 10200 ELBO: -272.6 KL: 298.026 Reconstruction: 25.4262 Entropy: -467.281
# Iteration: 10300 ELBO: -272.986 KL: 298.44 Reconstruction: 25.4538 Entropy: -470.523
# Iteration: 10400 ELBO: -272.22 KL: 297.664 Reconstruction: 25.4432 Entropy: -469.443
# Iteration: 10500 ELBO: -271.257 KL: 296.712 Reconstruction: 25.4548 Entropy: -471.535
# Iteration: 10600 ELBO: -271.643 KL: 297.106 Reconstruction: 25.4636 Entropy: -472.987
# Iteration: 10700 ELBO: -272.221 KL: 297.668 Reconstruction: 25.447 Entropy: -470.883
# Iteration: 10800 ELBO: -272.193 KL: 297.645 Reconstruction: 25.4525 Entropy: -471.967
# Iteration: 10900 ELBO: -272.629 KL: 298.071 Reconstruction: 25.4416 Entropy: -470.155
# Iteration: 11000 ELBO: -272.4 KL: 297.852 Reconstruction: 25.4519 Entropy: -472.376
# Iteration: 11100 ELBO: -272.171 KL: 297.616 Reconstruction: 25.4443 Entropy: -470.304
# Iteration: 11200 ELBO: -271.863 KL: 297.305 Reconstruction: 25.4413 Entropy: -471.188
# Iteration: 11300 ELBO: -272.658 KL: 298.111 Reconstruction: 25.4535 Entropy: -473.713
# Iteration: 11400 ELBO: -272.462 KL: 297.92 Reconstruction: 25.4579 Entropy: -473.123
# Iteration: 11500 ELBO: -272.148 KL: 297.608 Reconstruction: 25.4603 Entropy: -472.874
# Iteration: 11600 ELBO: -272.717 KL: 298.179 Reconstruction: 25.4619 Entropy: -473.966
# Iteration: 11700 ELBO: -272.323 KL: 297.779 Reconstruction: 25.4557 Entropy: -472.978
# Iteration: 11800 ELBO: -272.031 KL: 297.497 Reconstruction: 25.4659 Entropy: -473.469
# Iteration: 11900 ELBO: -271.915 KL: 297.362 Reconstruction: 25.4463 Entropy: -470.085
# Iteration: 12000 ELBO: -272.658 KL: 298.115 Reconstruction: 25.4563 Entropy: -473.072
# Iteration: 12100 ELBO: -272.402 KL: 297.851 Reconstruction: 25.4491 Entropy: -470.678
# Iteration: 12200 ELBO: -272.021 KL: 297.483 Reconstruction: 25.4613 Entropy: -474.297
# Iteration: 12300 ELBO: -272.485 KL: 297.956 Reconstruction: 25.4709 Entropy: -476.742
# Iteration: 12400 ELBO: -272.333 KL: 297.779 Reconstruction: 25.4456 Entropy: -470.138
# Iteration: 12500 ELBO: -273.223 KL: 298.683 Reconstruction: 25.4599 Entropy: -472.349
# Iteration: 12600 ELBO: -272.47 KL: 297.934 Reconstruction: 25.4636 Entropy: -473.553
# Iteration: 12700 ELBO: -271.915 KL: 297.383 Reconstruction: 25.4683 Entropy: -476.796
# Iteration: 12800 ELBO: -272.84 KL: 298.305 Reconstruction: 25.4642 Entropy: -473.766
# Iteration: 12900 ELBO: -271.792 KL: 297.263 Reconstruction: 25.4711 Entropy: -476.473
# Iteration: 13000 ELBO: -272.16 KL: 297.623 Reconstruction: 25.4634 Entropy: -474.747
# Iteration: 13100 ELBO: -271.301 KL: 296.754 Reconstruction: 25.4536 Entropy: -474.288
# Iteration: 13200 ELBO: -272.423 KL: 297.876 Reconstruction: 25.4529 Entropy: -475.668
# Iteration: 13300 ELBO: -272.58 KL: 298.033 Reconstruction: 25.4533 Entropy: -474.277
# Iteration: 13400 ELBO: -271.893 KL: 297.362 Reconstruction: 25.4686 Entropy: -477.192
# Iteration: 13500 ELBO: -274.315 KL: 299.764 Reconstruction: 25.4486 Entropy: -474.365
# Iteration: 13600 ELBO: -272.309 KL: 297.769 Reconstruction: 25.46 Entropy: -473.961
# Iteration: 13700 ELBO: -272.103 KL: 297.558 Reconstruction: 25.4552 Entropy: -473.585
# Iteration: 13800 ELBO: -272.196 KL: 297.649 Reconstruction: 25.4528 Entropy: -474.326
# Iteration: 13900 ELBO: -272.308 KL: 297.776 Reconstruction: 25.4676 Entropy: -474.69
# Iteration: 14000 ELBO: -272.539 KL: 298.002 Reconstruction: 25.4635 Entropy: -476.021
# Iteration: 14100 ELBO: -273.002 KL: 298.466 Reconstruction: 25.4639 Entropy: -474.645
# Iteration: 14200 ELBO: -272.737 KL: 298.198 Reconstruction: 25.4612 Entropy: -472.822
# Iteration: 14300 ELBO: -272.082 KL: 297.544 Reconstruction: 25.462 Entropy: -475.243
# Iteration: 14400 ELBO: -272.393 KL: 297.854 Reconstruction: 25.4612 Entropy: -476.12
# Iteration: 14500 ELBO: -272.363 KL: 297.833 Reconstruction: 25.4703 Entropy: -475.785
# Iteration: 14600 ELBO: -272.112 KL: 297.582 Reconstruction: 25.4696 Entropy: -476.367
# Iteration: 14700 ELBO: -271.954 KL: 297.404 Reconstruction: 25.4501 Entropy: -473.849
# Iteration: 14800 ELBO: -272.23 KL: 297.685 Reconstruction: 25.4554 Entropy: -476.191
# Iteration: 14900 ELBO: -272.578 KL: 298.037 Reconstruction: 25.4588 Entropy: -475.968
# Iteration: 15000 ELBO: -271.757 KL: 297.214 Reconstruction: 25.4571 Entropy: -473.417
# Iteration: 15100 ELBO: -272.488 KL: 297.938 Reconstruction: 25.4494 Entropy: -474.096
# Iteration: 15200 ELBO: -273.426 KL: 298.894 Reconstruction: 25.4686 Entropy: -477.116
# Iteration: 15300 ELBO: -273.928 KL: 299.394 Reconstruction: 25.4665 Entropy: -478.348
# Iteration: 15400 ELBO: -272.922 KL: 298.39 Reconstruction: 25.468 Entropy: -475.179
# Iteration: 15500 ELBO: -271.847 KL: 297.301 Reconstruction: 25.4532 Entropy: -475.205
# Iteration: 15600 ELBO: -273.001 KL: 298.462 Reconstruction: 25.4618 Entropy: -476.128
# Iteration: 15700 ELBO: -272.486 KL: 297.958 Reconstruction: 25.4718 Entropy: -476.949
# Iteration: 15800 ELBO: -272.626 KL: 298.098 Reconstruction: 25.4713 Entropy: -475.843
# Iteration: 15900 ELBO: -272.252 KL: 297.723 Reconstruction: 25.4708 Entropy: -476.438
# Iteration: 16000 ELBO: -272.1 KL: 297.566 Reconstruction: 25.4663 Entropy: -476.064
# Iteration: 16100 ELBO: -271.788 KL: 297.252 Reconstruction: 25.4648 Entropy: -476.25
# Iteration: 16200 ELBO: -272.946 KL: 298.402 Reconstruction: 25.4558 Entropy: -477.545
# Iteration: 16300 ELBO: -272.424 KL: 297.89 Reconstruction: 25.4657 Entropy: -475.364
# Iteration: 16400 ELBO: -272.209 KL: 297.667 Reconstruction: 25.4581 Entropy: -476.909
# Iteration: 16500 ELBO: -272.134 KL: 297.601 Reconstruction: 25.4669 Entropy: -476.318
# Iteration: 16600 ELBO: -271.703 KL: 297.168 Reconstruction: 25.4652 Entropy: -478.37
# Iteration: 16700 ELBO: -271.913 KL: 297.388 Reconstruction: 25.4752 Entropy: -477.495
# Iteration: 16800 ELBO: -273.395 KL: 298.864 Reconstruction: 25.4699 Entropy: -476.776
# Iteration: 16900 ELBO: -272.216 KL: 297.68 Reconstruction: 25.4643 Entropy: -476.855
# Iteration: 17000 ELBO: -271.904 KL: 297.375 Reconstruction: 25.4705 Entropy: -476.041
# Iteration: 17100 ELBO: -272.385 KL: 297.834 Reconstruction: 25.4489 Entropy: -473.365
# Iteration: 17200 ELBO: -272.022 KL: 297.491 Reconstruction: 25.4686 Entropy: -475.901
# Iteration: 17300 ELBO: -271.315 KL: 296.785 Reconstruction: 25.4708 Entropy: -475.528
# Iteration: 17400 ELBO: -272.638 KL: 298.114 Reconstruction: 25.4762 Entropy: -476.591
# Iteration: 17500 ELBO: -271.792 KL: 297.256 Reconstruction: 25.4639 Entropy: -477.302
# Iteration: 17600 ELBO: -272.098 KL: 297.558 Reconstruction: 25.4604 Entropy: -475.173
# Iteration: 17700 ELBO: -271.906 KL: 297.373 Reconstruction: 25.4673 Entropy: -477.983
# Iteration: 17800 ELBO: -272.658 KL: 298.14 Reconstruction: 25.4817 Entropy: -477.741
# Iteration: 17900 ELBO: -271.572 KL: 297.041 Reconstruction: 25.4694 Entropy: -474.658
# Iteration: 18000 ELBO: -273.415 KL: 298.883 Reconstruction: 25.4671 Entropy: -476.087
# Iteration: 18100 ELBO: -271.959 KL: 297.424 Reconstruction: 25.4652 Entropy: -476.923
# Iteration: 18200 ELBO: -272.958 KL: 298.422 Reconstruction: 25.4645 Entropy: -477.253
# Iteration: 18300 ELBO: -271.613 KL: 297.059 Reconstruction: 25.4463 Entropy: -476.244
# Iteration: 18400 ELBO: -272.005 KL: 297.47 Reconstruction: 25.4641 Entropy: -475.02
# Iteration: 18500 ELBO: -271.53 KL: 296.979 Reconstruction: 25.449 Entropy: -473.761
# Iteration: 18600 ELBO: -274.095 KL: 299.568 Reconstruction: 25.4724 Entropy: -476.427
# Iteration: 18700 ELBO: -272.253 KL: 297.727 Reconstruction: 25.4746 Entropy: -476.911
# Iteration: 18800 ELBO: -272.219 KL: 297.682 Reconstruction: 25.4637 Entropy: -476.172
# Iteration: 18900 ELBO: -271.405 KL: 296.873 Reconstruction: 25.4685 Entropy: -476.7
# Iteration: 19000 ELBO: -271.175 KL: 296.646 Reconstruction: 25.4705 Entropy: -476.684
# Iteration: 19100 ELBO: -271.797 KL: 297.247 Reconstruction: 25.4495 Entropy: -473.988
# Iteration: 19200 ELBO: -271.75 KL: 297.221 Reconstruction: 25.4706 Entropy: -476.497
# Iteration: 19300 ELBO: -272.454 KL: 297.918 Reconstruction: 25.4646 Entropy: -476.141
# Iteration: 19400 ELBO: -271.85 KL: 297.301 Reconstruction: 25.4516 Entropy: -474.387
# Iteration: 19500 ELBO: -272.01 KL: 297.478 Reconstruction: 25.4674 Entropy: -476.106
# Iteration: 19600 ELBO: -272.599 KL: 298.059 Reconstruction: 25.4597 Entropy: -475.595
# Iteration: 19700 ELBO: -271.959 KL: 297.404 Reconstruction: 25.4457 Entropy: -471.373
# Iteration: 19800 ELBO: -272.453 KL: 297.916 Reconstruction: 25.4634 Entropy: -475.192
# Iteration: 19900 ELBO: -273.455 KL: 298.927 Reconstruction: 25.472 Entropy: -476.884
# Iteration: 20000 ELBO: -272.183 KL: 297.649 Reconstruction: 25.4661 Entropy: -474.748
# Iteration: 20100 ELBO: -271.775 KL: 297.229 Reconstruction: 25.4541 Entropy: -474.58
# Iteration: 20200 ELBO: -272.007 KL: 297.47 Reconstruction: 25.4632 Entropy: -475.143
# Iteration: 20300 ELBO: -272.415 KL: 297.887 Reconstruction: 25.4723 Entropy: -475.364
# Iteration: 20400 ELBO: -272.537 KL: 298.015 Reconstruction: 25.4781 Entropy: -477.078
# Iteration: 20500 ELBO: -272.069 KL: 297.538 Reconstruction: 25.4692 Entropy: -475.679
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-b6396c6aa586> in <module>()
#      20     post_means.append(sess.run(tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES, 'make_posterior/post_means:0'))[0])
#      21     post_stddevs.append(sess.run(gen_model._post_stddev))
# ---> 22     m = sess.run(gen_model.make_transitional, {x_: batch[..., None]})
#      23     s = sess.run(gen_model.trans_std, {x_: batch[..., None]})
#      24     means.append(m); stds.append(s); gen_stddevs.append(sess.run(gen_model.gen_std, {x_: batch[..., None]}))
#
# /opt/miniconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     887     try:
#     888       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 889                          run_metadata_ptr)
#     890       if run_metadata:
#     891         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /opt/miniconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1118     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1119       results = self._do_run(handle, final_targets, final_fetches,
# -> 1120                              feed_dict_tensor, options, run_metadata)
#    1121     else:
#    1122       results = []
#
# /opt/miniconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1315     if handle is None:
#    1316       return self._do_call(_run_fn, self._session, feeds, fetches, targets,
# -> 1317                            options, run_metadata)
#    1318     else:
#    1319       return self._do_call(_prun_fn, self._session, handle, feeds, fetches)
#
# /opt/miniconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1321   def _do_call(self, fn, *args):
#    1322     try:
# -> 1323       return fn(*args)
#    1324     except errors.OpError as e:
#    1325       message = compat.as_text(e.message)
#
# /opt/miniconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1300           return tf_session.TF_Run(session, options,
#    1301                                    feed_dict, fetch_list, target_list,
# -> 1302                                    status, run_metadata)
#    1303
#    1304     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
plt.plot(np.squeeze(np.array(post_stddevs))[1000:], label='post sigma')
plt.plot(gen_stddevs[1000:], label='gen sigma')
plt.plot([np.mean(s) for s in stds][1000:], label='trans. sigmas')
plt.legend();

# %%
plt.plot(np.squeeze(np.array(post_stddevs))[1000:], label='post sigma')
plt.plot(gen_stddevs[1000:], label='gen sigma')
plt.plot([np.mean(s) for s in stds][1000:], label='trans. sigmas')
plt.legend();

# %%
plt.plot(np.squeeze(np.array(post_stddevs))[1000:], label='post sigma')
plt.plot(gen_stddevs[1000:], label='gen sigma')
plt.plot([np.mean(s) for s in stds][1000:], label='trans. sigmas')
plt.legend();

# %%
plt.plot(ts[:70], 'b', label='data')
plt.plot(np.mean(means[-1], 0), 'r-', label='transitional means')
# plt.plot(stds[-1], 'k', label='transitional stddev')
plt.plot(np.mean(np.stack(latents, 0), 0), 'g', label='posterior sample')
plt.plot(np.mean(sess.run(gen_model.make_posterior.mean() , {x_: batch[..., None]}), 0), label='posterior means')
plt.plot(y[:70], label='true sinusoid')
plt.legend();

# %%
plt.plot(ts[:70], 'b', label='data')
plt.plot(np.mean(means[-1], 0), 'r-', label='transitional means')
plt.plot(stds[-1], 'k', label='transitional stddev')
plt.plot(np.mean(np.stack(latents, 0), 0), 'g', label='posterior sample')
plt.plot(np.mean(sess.run(gen_model.make_posterior.mean() , {x_: batch[..., None]}), 0), label='posterior means')
plt.plot(y[:70], label='true sinusoid')
plt.legend();

# %%
plt.plot(ts[:70], 'b', label='data')
plt.plot(np.mean(means[-1], 0), 'r-', label='transitional means')
plt.plot(stds[-1], 'k', label='transitional stddev')
plt.plot(np.mean(np.stack(latents, 0), 0), 'g', label='posterior sample')
plt.plot(np.mean(sess.run(gen_model.make_posterior.mean() , {x_: batch[..., None]}), 0), label='posterior means')
plt.plot(y[:70], label='true sinusoid')
plt.legend();
